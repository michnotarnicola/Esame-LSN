# %% [markdown]
# # <span style="color:blue"> Esercitazione 12 </span>

# %% [markdown]
# #### NOTA PER IL LETTORE:
# La struttura del paper segue le linee guida dettate nella precedente esercitazione, con l'alternanza di codice e parole.

# %% [markdown]
# ### <span style="color:red"> Preminaries: upload delle librerie e del dataset MNIST

# %%
import tensorflow as tf
from tensorflow import keras
import os
import numpy as np
import matplotlib.pyplot as plt
seed=0
np.random.seed(seed) # fix random seed
tf.random.set_seed(seed)

# %%
from tensorflow.keras.datasets import mnist

# input image dimensions
img_rows, img_cols = 28, 28 # number of pixels 
# output
num_classes = 10 # 10 digits

# the data, split between train and test sets
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

print('X_train shape:', X_train.shape)
print('Y_train shape:', Y_train.shape)
print()
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (60000, 28, 28)
# Y_train shape: (60000,)
#
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## <span style="color:blue"> Esercizio 1
#
# ### Scopo dell'esercizio
#
# Lo scopo dell'esercizio è quello di testare la rete DNN presentata per riconoscimento delle cifre da $0$ a $9$, analizzandone il funzionamento al variare dei possibili ottimizzatori. <p>
#
# ### Discussione del lavoro
# ### <span style="color:red"> Fase 1: definizione della rete neurale profonda DNN
# Qui di seguito sono riportate le linee di codice che creano e inizializzano la rete feed forward utilizzata. <p>
# L'input corrisponde a un'immagine 28x28 "srotolata" in un array unimensionale di size 784, mentre l'output consiste di un intero tra 0 e 9, vale a dire la previsione della cifra rappresentata nel dato in ingresso. <p>
# La rete ha un'**architettura** tipo $784 \rightarrow 400 \rightarrow 100 \rightarrow 100 \rightarrow 10$. Gli hidden layer hanno come funzione di attivazione la *ReLu*, mentre il layer di output usa una *Softmax*, visto che ha da risolvere un problema di classificazione. <p>
# La funzione loss scelta è stata la *Categorical Cross Entropy*, come metrica invece la *Accuracy*. L'ottimizzatore è stato variato esplorando varie possibilità. Qui di seguito è stato mantenuto lo *Stochastic Gradient Discent*.

# %%
# reshape data, it could depend on Keras backend
X_train = X_train.reshape(X_train.shape[0], img_rows*img_cols)
X_test = X_test.reshape(X_test.shape[0], img_rows*img_cols)

# cast floats to single precesion
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# rescale data in interval [0,1]
X_train /= 255
X_test /= 255

##------ look at an example of data point------#
#print('an example of a data point with label', Y_train[20])
# matshow: display a matrix in a new figure window
#plt.matshow(X_train[20,:].reshape(28,28),cmap='binary')
#plt.show()

##------print('an example of a data point with label', Y_train[20], 'before to_categorical ...')------#
# convert class vectors to binary class matrices, e.g. for use with categorical_crossentropy
Y_train = keras.utils.to_categorical(Y_train, num_classes)
Y_test = keras.utils.to_categorical(Y_test, num_classes)
#print('... and with label', Y_train[20], 'after to_categorical')
#print()
print('X_train shape:', X_train.shape)
print('Y_train shape:', Y_train.shape)
# Out:
# X_train shape: (60000, 784)
# Y_train shape: (60000, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

def create_DNN():
    # instantiate model
    model = Sequential()
    # add a dense all-to-all relu layer
    model.add(Dense(400,input_shape=(img_rows*img_cols,), activation='relu'))
    # add a dense all-to-all relu layer
    model.add(Dense(100, activation='relu'))
    # apply dropout with rate 0.5
    model.add(Dropout(0.5))
    # soft-max layer
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

print('Model architecture created successfully!')
# Out:
# Model architecture created successfully!

# %%
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta, Adam, Adamax, Nadam

def compile_model():
    # create the model
    model=create_DNN()
    # compile the model
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer=SGD(),
                  metrics=['accuracy'])
    return model

# create the deep neural net
model_DNN = compile_model()

print('Model compiled successfully and ready to be trained.')
# Out:
# Model compiled successfully and ready to be trained.

# %% [markdown]
# ### <span style="color:red"> Fase 2: training del modello
#
# Una volta creata la rete, si è proceduto alla fase di training. Il dataset di training è stato diviso in 32 minibatches e il numero di epoche scelto è stato pari a 20.

# %%
# training parameters
batch_size = 32
epochs = 20

# train DNN and store training info in history
history = model_DNN.fit(X_train, Y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.7280 - accuracy: 0.7886 - val_loss: 0.3029 - val_accuracy: 0.9175
# Epoch 2/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3727 - accuracy: 0.8942 - val_loss: 0.2340 - val_accuracy: 0.9322
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3017 - accuracy: 0.9161 - val_loss: 0.1969 - val_accuracy: 0.9423
# Epoch 4/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2597 - accuracy: 0.9277 - val_loss: 0.1722 - val_accuracy: 0.9478
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2301 - accuracy: 0.9354 - val_loss: 0.1572 - val_accuracy: 0.9501
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2069 - accuracy: 0.9418 - val_loss: 0.1430 - val_accuracy: 0.9545
# Epoch 7/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1882 - accuracy: 0.9469 - val_loss: 0.1302 - val_accuracy: 0.9580
# Epoch 8/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1731 - accuracy: 0.9514 - val_loss: 0.1227 - val_accuracy: 0.9611
# Epoch 9/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1627 - accuracy: 0.9543 - val_loss: 0.1145 - val_accuracy: 0.9647
# Epoch 10/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1525 - accuracy: 0.9560 - val_loss: 0.1089 - val_accuracy: 0.9656
# Epoch 11/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1412 - accuracy: 0.9599 - val_loss: 0.1039 - val_accuracy: 0.9664
# Epoch 12/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1321 - accuracy: 0.9629 - val_loss: 0.0995 - val_accuracy: 0.9689
# Epoch 13/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1257 - accuracy: 0.9643 - val_loss: 0.0955 - val_accuracy: 0.9707
# Epoch 14/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1198 - accuracy: 0.9661 - val_loss: 0.0898 - val_accuracy: 0.9707
# Epoch 15/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1120 - accuracy: 0.9684 - val_loss: 0.0862 - val_accuracy: 0.9721
# Epoch 16/20
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1056 - accuracy: 0.9705 - val_loss: 0.0865 - val_accuracy: 0.9723
# Epoch 17/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1012 - accuracy: 0.9713 - val_loss: 0.0819 - val_accuracy: 0.9739
# Epoch 18/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0978 - accuracy: 0.9725 - val_loss: 0.0804 - val_accuracy: 0.9748
# Epoch 19/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0928 - accuracy: 0.9736 - val_loss: 0.0788 - val_accuracy: 0.9746
# Epoch 20/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0889 - accuracy: 0.9745 - val_loss: 0.0769 - val_accuracy: 0.9751

# %% [markdown]
# ### <span style="color:red"> Fase 3: applicazione della rete 'trainata' al dataset di test
#
# Di seguito sono riportati l'andamento della funzione loss e accuracy dei due dataset in funzione del numero di epoche.

# %%
# evaluate model
score = model_DNN.evaluate(X_test, Y_test, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# look into training history

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Optimizer: SGD')
plt.ylabel('Model accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='best')
plt.grid()
#plt.savefig('accuracySGD.png')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Optimizer: SGD')
plt.ylabel('Model loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='best')
plt.grid()
#plt.savefig('lossSGD.png')
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0769 - accuracy: 0.9751
#
# Test loss: 0.0768543928861618
# Test accuracy: 0.9750999808311462

# %% [markdown]
# La funzione costo sul dataset di training tende a decrescere con l'aumentare delle epoche e ad avvicinarsi alla curva del dataset di test. Questo è il segnale che la rete sta imparando, ma non è ancora giunta alla fase di overfitting. I dati di test mostrano una loss inferiore solamente perchè per loro non si attiva il layer di dropout. Lo stesso ragionamento a rovescio si può fare per il grafico della accuracy. <p>
# Infine, in basso sono riportati i risultati predetti dalla rete su alcuni dati del dataset di test. Come si piò osservare, tutte le lettere sono riconosciute, segnale di un buon apprendimento.

# %%
#X_test = X_test.reshape(X_test.shape[0], img_rows*img_cols)
predictions = model_DNN.predict(X_test)

X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols,1)

plt.figure(figsize=(15, 15)) 
for i in range(10):    
    ax = plt.subplot(2, 10, i + 1)    
    plt.imshow(X_test[i, :, :, 0], cmap='gray')    
    plt.title("Digit: {}\nPredicted:    {}".format(np.argmax(Y_test[i]), np.argmax(predictions[i])))    
    plt.axis('off') 
plt.show()

# %% [markdown]
# **Considerazioni analoghe a quelle finora raccontate sono state svolte provando a variare l'ottimizzatore utilizzato dalla rete.** Si è testato la rete appena descritta con due ottimizzatori diversi: l'**Adagrad** e l'**Adadelta**. Gli andamenti della loss e della accuracy sono stati i seguenti:

# %% [markdown]
# **ADAGRAD:** <p>
# Test loss: 0.20334061980247498 <p>
# Test accuracy: 0.9412999749183655

# %%
from IPython.display import HTML, display
display(HTML("<table><tr><td><img src='accuracyADAGRAD.png'></td><td><img src='lossADAGRAD.png'></td></tr></table>"))
# Out:
# <table><tr><td><img src='accuracyADAGRAD.png'></td><td><img src='lossADAGRAD.png'></td></tr></table>

# %% [markdown]
# **ADADELTA:** <p>
# Test loss: 0.547890841960907 <p>
# Test accuracy: 0.8845999836921692

# %%
from IPython.display import HTML, display
display(HTML("<table><tr><td><img src='accuracyADADELTA.png'></td><td><img src='lossADADELTA.png'></td></tr></table>"))
# Out:
# <table><tr><td><img src='accuracyADADELTA.png'></td><td><img src='lossADADELTA.png'></td></tr></table>

# %% [markdown]
# L'andamento delle loss e delle accuracy è sostanzialmente analogo a quanto accade nel caso dello SGD. In questi due casi, però, l'apprendimento risulta più lento e saranno necessarie più epoche per poter raggiungere il livello di accuracy del 97.5 % mostrato dallo SGD. Infatti, testando la rete sui dieci input visti in precedenza solo 9 su 10 sono correttamente predetti. La penultima cifra, un cinque particolarmente scritto male, viene scambiato per un 6 dalla rete che usa l'Adagrad e un 4 da quella dell'Adadelta.

# %% [markdown]
# ## <span style="color:blue"> Esercizio 2 & 3
#
# ### Scopo dell'esercizio
#
# Lo scopo dell'esercizio è quello di risolvere il problema delle cifre implementando una rete CNN e, dopo averla trainata, di testarla su cifre scritte a mano da noi stessi. <p>
#
# ### Discussione del lavoro
# ### <span style="color:red"> Fase 1: definizione della rete neurale convoluzionale CNN
# Si è ripartiti dal dataset caricato da MNIST e, questa volta, gli input sono stati riscritti sottoforma di tensori 3D 28x28x1(dove 1 rappresenta il fatto che si lavora in scala di grigi). Gli output, chiaramente, sono ancora interi da 0 a 9. L'architettura della rete è una leggera modifica di quella del sitoweb www.cs.ryerson.ca~aharley/vis/conv/flat.html, del tipo $1 \rightarrow 8 \rightarrow 8 \rightarrow 16 \rightarrow 16 \rightarrow 120 \rightarrow 120 \rightarrow 10$. Lo schema della rete è riportato in basso. Come loss e accuracy sono state mantenute quelle precedenti e come ottimizzatore si è ancora scelto lo SGD.

# %%
# you will need the following for Convolutional Neural Networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

# reshape data, depending on Keras backend
if keras.backend.image_data_format() == 'channels_first':
    X_train = X_train.reshape(X_train.shape[0], 1, img_rows, img_cols)
    X_test = X_test.reshape(X_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
    X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# convert class vectors to binary class matrices, e.g. for use with categorical_crossentropy
Y_train = keras.utils.to_categorical(Y_train, num_classes)
Y_test = keras.utils.to_categorical(Y_test, num_classes)
    
print('X_train shape:', X_train.shape)
print('Y_train shape:', Y_train.shape)
print()
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (60000, 28, 28, 1)
# Y_train shape: (60000, 10)
#
# 60000 train samples
# 10000 test samples

# %%
def create_CNN():
    # instantiate model
    model = Sequential()
    # add first convolutional layer with 8 filters
    model.add(Conv2D(8, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
    # add first pooling layer
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # add second convolutional layer with 16 filters
    model.add(Conv2D(16, kernel_size=(3,3), activation='relu'))
    # add second pooling layer
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # flatten the neurons
    model.add(Flatten())
    # add a fully connected layer
    model.add(Dense(120, activation='relu'))
    # add a dropout layer
    model.add(Dropout(0.5))
    # add the final layer
    model.add(Dense(num_classes, activation='softmax'))


    # compile the model
    model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer='SGD',
                  metrics=['accuracy'])
    return model

# create the deep conv net
model_CNN=create_CNN()

print('Model compiled successfully and ready to be trained.')
# Out:
# Model compiled successfully and ready to be trained.

# %%
model_CNN.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 26, 26, 8)         80
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 13, 13, 8)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 11, 11, 16)        1168
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 120)               48120
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                1210
# =================================================================
# Total params: 50,578
# Trainable params: 50,578
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### <span style="color:red"> Fase 2: training del modello
#
# Il dataset di training è stato diviso ancora in 5 minibatches e il numero di epoche scelto è stato pari a 5.

# %%
# training parameters
batch_size = 5
epochs = 5

# train CNN
history = model_CNN.fit(X_train, Y_train,
          batch_size=batch_size,
          epochs=epochs, shuffle=True,
          verbose=1,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/5
# 12000/12000 [==============================] - 43s 4ms/step - loss: 0.3721 - accuracy: 0.8840 - val_loss: 0.2043 - val_accuracy: 0.9350
# Epoch 2/5
# 12000/12000 [==============================] - 44s 4ms/step - loss: 0.3007 - accuracy: 0.9079 - val_loss: 0.1960 - val_accuracy: 0.9362
# Epoch 3/5
# 12000/12000 [==============================] - 44s 4ms/step - loss: 0.2615 - accuracy: 0.9195 - val_loss: 0.1710 - val_accuracy: 0.9441
# Epoch 4/5
# 12000/12000 [==============================] - 43s 4ms/step - loss: 0.2433 - accuracy: 0.9241 - val_loss: 0.1563 - val_accuracy: 0.9490
# Epoch 5/5
# 12000/12000 [==============================] - 44s 4ms/step - loss: 0.2260 - accuracy: 0.9301 - val_loss: 0.1504 - val_accuracy: 0.9533

# %% [markdown]
# ### <span style="color:red"> Fase 3: applicazione della rete 'trainata' al dataset di test e alle cifre scritte a mano
#
# Di seguito sono riportati l'andamento della funzione loss e accuracy dei due dataset in funzione del numero di epoche.

# %%
# evaluate model
score = model_CNN.evaluate(X_test, Y_test, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# look into training history

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Optimizer: SGD')
plt.ylabel('Model accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='best')
plt.grid()
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Optimizer: SGD')
plt.ylabel('Model loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='best')
plt.grid()
plt.show()
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1504 - accuracy: 0.9533
#
# Test loss: 0.150405153632164
# Test accuracy: 0.9532999992370605

# %% [markdown]
# Si conferma l'andamento decrescente della loss e crescente della accuracy, con le due curve di test e train che tendono ad avvicinarsi tra loro. <p>
#
# Come azione finale, la rete è stata applicata sia ai dati di test, sia alle lettere scritte a mano dal sottoscritto. Il risultato sui 10 **dati estratti dal dataset di MNIST** è il seguente:

# %%
#X_test = X_test.reshape(X_test.shape[0], img_rows*img_cols)
predictions = model_CNN.predict(X_test)

X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols,1)

plt.figure(figsize=(15, 15)) 
for i in range(10):    
    ax = plt.subplot(2, 10, i + 1)    
    plt.imshow(X_test[i, :, :, 0], cmap='gray')    
    plt.title("Digit: {}\nPredicted:    {}".format(np.argmax(Y_test[i]), np.argmax(predictions[i])))    
    plt.axis('off') 
plt.show()

# %% [markdown]
# Il risultato sulle **cifre manoscritte** è, invece, riportato in basso.

# %%
from PIL import Image
import os

plt.figure(figsize=(15, 15)) 
for i in range(10): 
    ax= plt.subplot(2, 10, i + 1) 
    digit_filename = "./Pictures/"+str(i)+".png"
    digit_in = Image.open(digit_filename).convert('L')
    ydim, xdim = digit_in.size
    pix=digit_in.load();
    data = np.zeros((xdim, ydim))
    for j in range(ydim):
        for i in range(xdim):
            data[i,j]=pix[j,i]
    data /= 255
    data = data.reshape(1,xdim, ydim, 1) #reshape the picture to conform to the input of CNN
    pred_0 = model_CNN.predict(data) #predict the digit and then reshape back the picture
    data = data.reshape(xdim,ydim)
   
    plt.imshow(data, cmap='gray')    
    plt.title("Digit \nPredicted:    {}".format(np.argmax(pred_0)))    
    plt.axis('off') 
plt.show()

# %% [markdown]
# Tutte le cifre sono state riconosciute. Per completezza, sono state proposte **le stesse cifre scritte a mano anche alla rete DNN sviluppata nell'esercizio 1**. I risultati sono mostrati in basso. Anche in questo caso la rete ha riconosciuto tutte le cifre proposte.

# %%
from PIL import Image
import os

plt.figure(figsize=(15, 15)) 
for i in range(10): 
    ax= plt.subplot(2, 10, i + 1) 
    digit_filename = "./Pictures/"+str(i)+".png"
    digit_in = Image.open(digit_filename).convert('L')
    ydim, xdim = digit_in.size
    pix=digit_in.load();
    data = np.zeros((xdim, ydim))
    for j in range(ydim):
        for i in range(xdim):
            data[i,j]=pix[j,i]
    data /= 255
    data = data.reshape(1,xdim*ydim) #reshape the picture to conform to the input of CNN
    pred_0 = model_DNN.predict(data) #predict the digit and then reshape back the picture
    data = data.reshape(xdim,ydim)
   
    plt.imshow(data, cmap='gray')    
    plt.title("Digit \nPredicted:    {}".format(np.argmax(pred_0)))    
    plt.axis('off') 
plt.show()
